# %%
# %pip install matplotlib
# %pip install tensorflow
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/packaging-24.1.dist-info due to invalid metadata entry 'name'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 319.2 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 7.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.9/245.9 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.0 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# %pip install ipykernel
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/packaging-24.1.dist-info due to invalid metadata entry 'name'
# ...
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/packaging-24.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# ...
